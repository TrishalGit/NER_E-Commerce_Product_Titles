# %%
# importing the requests library
import requests
from bs4 import BeautifulSoup
  
# api-endpoint
URL = "https://www.amazon.com/s?k=sports+team+t-shirts&rh=n%3A3386071%2Cp_n_theme_browse-bin%3A374241011"
  
# sending get request and saving the response as response object
headers = {'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:80.0) Gecko/20100101 Firefox/80.0'}
r = requests.get(url = URL, headers=headers)
print(r.text)

# URL = "https://www.amazon.de/Bloodborne-Game-Year-PlayStation-4/dp/B016ZU4FIQ/ref=sr_1_3?ie=UTF8&qid=1519566642&sr=8-3&keywords=bloodborne+ps4"
page = requests.get(URL,headers={"User-Agent":"Defined"})
soup = BeautifulSoup(page.content, "html.parser")
# price = soup.find(id="priceblock_ourprice").get_text()
print(soup)
# Out:
# <!--
#         To discuss automated access to Amazon data please contact api-services-support@amazon.com.
#         For information about migrating to our APIs refer to our Marketplace APIs at https://developer.amazonservices.com/ref=rm_5_sv, or our Product Advertising API at https://affiliate-program.amazon.com/gp/advertising/api/detail/main.html/ref=rm_5_ac for advertising use cases.
# -->
# <!doctype html>
# <html>
# <head>
#   <meta charset="utf-8">
#   <meta http-equiv="x-ua-compatible" content="ie=edge">
#   <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
#   <title>Sorry! Something went wrong!</title>
#   <style>
#   html, body {
#     padding: 0;
#     margin: 0
#   }
#
#   img {
#     border: 0
#   }
#
#   #a {
#     background: #232f3e;
#     padding: 11px 11px 11px 192px
#   }
#
#   #b {
#     position: absolute;
#     left: 22px;
#     top: 12px
#   }
#
#   #c {
#     position: relative;
#     max-width: 800px;
# ...

# %%
import csv
import os

# Please use cookie from Postman request to amazon.com without a cookie we might not be able to accesss the website information
headers = {'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:80.0) Gecko/20100101 Firefox/80.0', 'Cookie': 'Use Personal cookie'}
response = requests.get('https://www.amazon.com/s?k=sports+team+t-shirts', headers=headers)
#print(response.text)
soup = BeautifulSoup(response.content, "html.parser")
price = soup.find(id="filters").get_text()
#print(price)
price = soup.find(id="brandsRefinements").get_text()
#print(price)
print("**********")
import re

price = soup.findAll('li')
price2 = soup.findAll('div')
features = []
for i in range(len(price2)):
    if(price2[i].get('id') is not None and "p_n_" in price2[i].get('id')):
        features.append((price2[i].get('id').replace('-title', ''), price2[i].text.strip()))
# print(features)
# print(price)
t = []
s = []
directory = os.getcwd()
# print(directory)
s = []
for i in range(len(price)):
    if(price[i].get('id') is not None and "p_89/" in price[i].get('id')):
        s.append([price[i].text.strip(), price[i].find('a').get('href')])
f = open(directory + '/filters/Brands.csv', 'w', newline='')
w = csv.writer(f, delimiter=",")
print(s)
w.writerows(s)
f.close()
    
for j in range(len(features)): 
    s = []
    print(features[j][0])
    for i in range(len(price)):
        if price[i].get('id') is not None and features[j][0] in price[i].get('id'):
            s.append([price[i].text.strip(), price[i].find('a').get('href')])
    f = open(directory + '/filters/' + features[j][1] + '.csv', 'w', newline='')
    w = csv.writer(f, delimiter=",")
    print(s)
    w.writerows(s)
    f.close()
# print(t)
# for i in range(len(s)):
#     print(s[i][0])
# f = open('/Users/gayamtrishal/Desktop/ASU/', 'w')

# # create the csv writer
# writer = csv.writer(f)

# # write a row to the csv file
# writer.writerow(row)

# # close the file
# f.close()
# Out:
# **********
# ...
